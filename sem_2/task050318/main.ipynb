# %%
from sem_2.task050318.task_1 import simple_gramma

# %% [markdown]
# ### Check regex

# %%
tst = 'It is a mistake to think you can solve any major problems just with potatoes. D. Adams'
print(tst)
print(' '.join(simple_gramma.custom_tokenize(tst)))
# Out:
# It is a mistake to think you can solve any major problems just with potatoes. D. Adams
# it is a mistake to think you can solve any major problems just with potatoes d. adams

# %%
raw_text = simple_gramma.read_file('sem_2/data/balabanov.txt')

tokens, txt = simple_gramma.nltk_tokenize(raw_text)

print('Task a:')
simple_gramma.part_a(txt)

print('\n Task b:')
cl_txt = simple_gramma.part_b(tokens)
simple_gramma.part_a(cl_txt)

print('\n Task v:')
ct_tokens = simple_gramma.part_v(raw_text)
simple_gramma.part_a(simple_gramma.part_b(ct_tokens))
# Out:
# Task a:
# ...

# %%
from sem_2.task050318.task_2 import homo_gramma

homo_gramma.run()
# Out:
# (S
#   (NP я)
#   (VP
#     (VP (V видел) (NP (Det его) (N семью)))
#     (PP (Det своими) (N глазами))))
# (S
#   (NP я)
#   (VP
#     (V видел)
#     (NP (Det его) (N семью) (PP (Det своими) (N глазами)))))
